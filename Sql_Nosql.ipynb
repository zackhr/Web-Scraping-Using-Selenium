# %% [markdown]
# <div class="alert alert-block alert-info" >
#     <center><h1>PARTIE 1 <h1></center>
# </div>

# %% [markdown]
# <h1>Création et Chargement des données dans la Base de Données MySQL</h1>

# %%
import pandas as pd
import pymysql
import sqlalchemy
from sqlalchemy import create_engine
from pandas.io import sql
import os
import os.path
Demographie=pd.read_excel(r'Demographie.xlsx',dtype=str)
Handicap=pd.read_excel(r'Handicap.xlsx',dtype=str)
Langue_local=pd.read_excel(r'Langue_local.xlsx',dtype=str)
Activite_emploi=pd.read_excel(r'Activite_emploi.xlsx',dtype=str)
Cond_habitat=pd.read_excel(r'Cond_habitat.xlsx',dtype=str)
Educ_Alphab=pd.read_excel(r'Educ_Alphab.xlsx',dtype=str)
commune=pd.read_excel(r'Rgph2014_Commune.xlsx',dtype=str)
province=pd.read_excel(r'Rgph2014_Province.xlsx',dtype=str)
region=pd.read_excel(r'Rgph2014_Region.xlsx',dtype=str)
maroc=pd.read_excel(r'Rgph2014_Maroc.xlsx',dtype=str)
user = 'root'
password = 'root'
localhost =  '127.0.0.1'  
port = '3306' 
database ='dbrgph2014'



engine = create_engine('mysql+mysqldb://user:password@localhost:3306/dbrgph2014')



commune.to_sql(con=engine,name='commune', if_exists='replace',index=False , dtype={ 
                   'population2014_ensemble_commune': sqlalchemy.types.INTEGER(),
                   
                   'age_moyen_mariage2014_ensemble_commune': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'taux_chaumage2014_ensemble_commune': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'taux_activite2014_feminin_commune': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'taux_analphabetisme2014_ensemble_commune': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    ' Taux_handicap2014_Ensemble_commune ' :sqlalchemy.types.Float(precision=3, asdecimal=True),
                     'taux_equipement_menage_Parabole2014_commune':sqlalchemy.types.Float(precision=3, asdecimal=True),
                      'taux_equipement_menage_Refrigerateur2014_commune':sqlalchemy.types.Float(precision=3, asdecimal=True)                                                             
                   })
province.to_sql(con=engine,name='Province', if_exists='replace',index=False ,dtype={'Taux_handicap2014_Ensemble_province': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'taux_analphabetisme2014_ensemble_province': sqlalchemy.types.Float(precision=3, asdecimal=True) ,
                    'tachl7it2014_ensemble_province': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'tamazight2014_ensemble_province': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'taux_equipement_menage_Parabole2014_province': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'taux_equipement_menage_Refrigerateur2014_province': sqlalchemy.types.Float(precision=3, asdecimal=True)
                     
                                                                                                                 
                
                })






region.to_sql(con=engine,name='Region', if_exists='replace',index=False ,dtype={'RE_age_moyen_mariage2014_masculin': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RE_age_moyen_mariage2014_feminin': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RU_age_moyen_mariage2014_masculin': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RU_age_moyen_mariage2014_feminin': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RR_age_moyen_mariage2014_masculin': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RR_age_moyen_mariage2014_feminin': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RE_Niveau_études_Néant_Ensemble': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RE_Niveau_études_Préscolaire_Ensemble': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RE_Niveau_études_Primaire_Ensemble': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RE_Niveau_études_collégial_Ensemble': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RE_Niveau_études_qualifiant_Ensemble': sqlalchemy.types.Float(precision=3, asdecimal=True),
                    'RE_Niveau_études_Supérieur_Ensemble': sqlalchemy.types.Float(precision=3, asdecimal=True)
                                                                                
                                                                               
                                                                               
                                                                               
                                                                               
                                                                               
                                                                               })








maroc.to_sql(con=engine,name='Maroc', if_exists='replace',index=False ,dtype={'population2014_ensemble_maroc': sqlalchemy.types.INTEGER()})
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\io\sql.py:1336: UserWarning: The provided table name 'Province' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\io\sql.py:1336: UserWarning: The provided table name 'Region' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\io\sql.py:1336: UserWarning: The provided table name 'Maroc' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# <h1> Interrogation de la BD MySQL</h1>

# %% [markdown]
# <h1>Question 4</h1>

# %%
#le total de la population municipale du Maroc
 
query = '''
 SELECT SUM(population2014_ensemble_province) as total_population
 from
 province
'''
pd.read_sql(query,engine)
#or
query = '''
 SELECT population2014_ensemble_maroc as total_population_municipal_maroc
 from
 maroc
'''
pd.read_sql(query,engine)
# Out:
#    total_population_municipal_maroc
# 0                          33610084

# %% [markdown]
# <h1>Question 5</h1>

# %%
#
query = '''
select  distinct population2014_ensemble_commune as dix_premieres_commune_peuplés,Nom_Commune2014 as nom_commune 
from commune order by population2014_ensemble_commune desc limit 10

 
 

'''
pd.read_sql(query,engine)
# Out:
#    dix_premieres_commune_peuplés  nom_commune
# 0                         517376       Meknès
# 1                         492873        Oujda
# 2                         467880  Hay-Hassani
# 3                         452863  Sidi Moumen
# 4                         423890      Kénitra
# 5                         420288       Agadir
# 6                         409829       Ménara
# 7                         385922   Bni Makada
# 8                         377866      Tétouan
# 9                         376772    Aîn-Chock

# %% [markdown]
# <h1>Question 6</h1>

# %%
#q6
query = '''
select count(Nom_Commune2014) as nombre_commune from commune where Region_Commune  NOT IN('Casablanca-Settat','Rabat-Salé-Kénitra') 
and (population2014_ensemble_commune >50000 and taux_chaumage2014_ensemble_commune <15 and taux_activite2014_feminin_commune >30 
and taux_analphabetisme2014_ensemble_commune <20)
'''
pd.read_sql(query,engine)
# Out:
#    nombre_commune
# 0               0

# %% [markdown]
# <h1>Question 7</h1>

# %%
#q7
query = '''
select Nom_province2014,Taux_handicap2014_Ensemble_province  from province order by Taux_handicap2014_Ensemble_province  LIMIT 5
'''
pd.read_sql(query,engine)
# Out:
#   Nom_province2014  Taux_handicap2014_Ensemble_province
# 0             None                                  NaN
# 1    Oued Ed-Dahab                                  2.4
# 2         Aousserd                                  2.5
# 3         Boujdour                                  2.7
# 4         Laâyoune                                  3.4

# %% [markdown]
# <h1>Question 8</h1>

# %%
#q8
query = '''
select Nom_region2014,RE_age_moyen_mariage2014_masculin,RE_age_moyen_mariage2014_feminin,RU_age_moyen_mariage2014_masculin,
RU_age_moyen_mariage2014_feminin,
RR_age_moyen_mariage2014_masculin,
RR_age_moyen_mariage2014_feminin from region  

'''
pd.read_sql(query,engine)
# Out:
#                Nom_region2014  RE_age_moyen_mariage2014_masculin  \
# 0   Tanger-Tetouan-Al Hoceima                               31.5
# 1                    Oriental                               32.5
# 2                  Fès-Meknès                               31.4
# 3          Rabat-Salé-Kénitra                               31.4
# 4        Béni Mellal-Khénifra                               30.6
# 5           Casablanca-Settat                               31.6
# 6              Marrakech-Safi                               30.4
# 7              Drâa-Tafilalet                               30.2
# 8                 Souss-Massa                               31.0
# 9           Guelmim-Oued Noun                               32.6
# 10    Laayoune-Sakia El Hamra                               32.2
# 11      Eddakhla-Oued Eddahab                               31.7
#
#     RE_age_moyen_mariage2014_feminin  RU_age_moyen_mariage2014_masculin  \
# ...

# %% [markdown]
# <h1>Question 9</h1>

# %%
#q 9
query = '''
 SELECT   Nom_province2014,Nom_Commune2014,taux_analphabetisme2014_ensemble_commune
 FROM commune INNER JOIN province
 ON commune.Code_Province=province.Code_province2014 
 order by taux_analphabetisme2014_ensemble_commune desc limit 10
'''
pd.read_sql(query,engine)
# Out:
#   Nom_province2014        Nom_Commune2014  \
# 0           Figuig            Bouchaouene
# 1         Taourirt         Oulad M'hammed
# 2         Boujdour        Gueltat Zemmour
# 3           Midelt                 Anemzi
# 4           Jerada  Oulad Sidi Abdelhakem
# 5       Taroudannt                Tindine
# 6        Essaouira            Tahelouante
# 7           Sefrou              Tafajight
# 8           Figuig               Maatarka
# 9          Tétouan      Oulad Ali Mansour
#
#    taux_analphabetisme2014_ensemble_commune
# 0                                      85.7
# 1                                      78.1
# 2                                      74.8
# 3                                      74.2
# 4                                      74.0
# 5                                      73.6
# 6                                      70.2
# 7                                      70.1
# 8                                      70.0
# 9                                      69.4

# %% [markdown]
# <h1>Question 10</h1>

# %%
#q10
query = '''
SELECT Nom_region2014,MAX(RE_Niveau_études_Néant_Ensemble) as Niveau_études_Néant ,MAX(RE_Niveau_études_Préscolaire_Ensemble) as Niveau_études_Préscolaire ,
MAX(RE_Niveau_études_Primaire_Ensemble) as Niveau_études_Primaire,
MAX(RE_Niveau_études_collégial_Ensemble) as Niveau_études_collégial_,MAX(RE_Niveau_études_qualifiant_Ensemble) as 
Niveau_études_qualifiant
,MAX(RE_Niveau_études_Supérieur_Ensemble) as Niveau_études_Supérieur

FROM region group by Nom_region2014 

'''
pd.read_sql(query,engine)
# Out:
#                Nom_region2014  Niveau_études_Néant  Niveau_études_Préscolaire  \
# 0        Béni Mellal-Khénifra                 43.3                        3.5
# 1           Casablanca-Settat                 31.4                        4.1
# 2              Drâa-Tafilalet                 39.6                        3.6
# 3       Eddakhla-Oued Eddahab                 28.6                        8.2
# 4                  Fès-Meknès                 38.9                        3.5
# 5           Guelmim-Oued Noun                 37.7                        6.4
# 6     Laayoune-Sakia El Hamra                 28.5                        6.1
# 7              Marrakech-Safi                 41.7                        4.6
# 8                    Oriental                 39.1                        3.4
# 9          Rabat-Salé-Kénitra                 34.1                        4.4
# 10                Souss-Massa                 37.3                        6.6
# ...

# %% [markdown]
# <h1>Question 11</h1>

# %%
#11
query = '''
select Nom_province2014 from province 
where (tachl7it2014_ensemble_province > tamazight2014_ensemble_province ) and 
((tachl7it2014_ensemble_province + tamazight2014_ensemble_province) >50)

'''
pd.read_sql(query,engine)
# Out:
#         Nom_province2014
# 0                   Tata
# 1   Agadir Ida Ou Tanane
# 2       Chtouka Ait Baha
# 3   Inezgane Ait Melloul
# 4             Ouarzazate
# 5              Sidi Ifni
# 6             Taroudannt
# 7                 Tiznit
# 8                 Zagora
# 9               Al Haouz
# 10             Chichaoua

# %% [markdown]
# <h1>Question 12</h1>

# %%
#12

query = '''
select count( Nom_province2014 ) from province where 
taux_equipement_menage_Parabole2014_province > taux_equipement_menage_Refrigerateur2014_province
'''
pd.read_sql(query,engine)
# Out:
#    count( Nom_province2014 )
# 0                         36

# %%
query = '''

CREATE OR REPLACE VIEW view_name AS
SELECT *
FROM commune INNER JOIN province ON commune.Code_Province=province.Code_province2014 
INNER JOIN region ON region.Nom_region2014=province.Region_province


'''
pd.read_sql(query,engine)

# %% [markdown]
# <div class="alert alert-block alert-info" >
#     <center><h1>PARTIE 2 <h1></center>
# </div>

# %% [markdown]
# <h1>Migration des données de la BD MySQL vers la BD MongoDB</h1>

# %%
from contextlib import closing
from datetime import datetime
import json
import MySQLdb
DB_NAME = 'dbrgph2014'
DB_USER = 'root'
DB_PASS = 'root'

def get_tables(cursor):
    cursor.execute('SHOW tables')
    return [r[0] for r in cursor.fetchall()] 

def get_rows_as_dicts(cursor, table):
    cursor.execute('select * from {}'.format(table))
    columns = [d[0] for d in cursor.description]
    return [dict(zip(columns, row)) for row in cursor.fetchall()]

def dump_date(thing):
    if isinstance(thing, datetime):
        return thing.isoformat()
    return str(thing)


with closing(MySQLdb.connect(user=DB_USER, passwd=DB_PASS, db=DB_NAME)) as conn, closing(conn.cursor()) as cursor:
    dump = {}
    for table in get_tables(cursor):
        dump[table] = get_rows_as_dicts(cursor, table)

# %%
for i in range(0,1687):
    dump['commune'][i]

# %%
import json
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client['dbrgph2014']
collection = db['commune']
#test=collection.insert_many(dump['commune'])

client.close()

# %% [markdown]
# <h1>Conception de cette BD MongoDB </h1>

# %%
#x=test.inserted_ids
dump
# Out:
# {'commune': [{'_id': '0',
#    'Code_Commune2014': '001.01.01',
#    'population2014_ensemble_commune': 420288,
#    'population2014_feminin_commune': '208766',
#    'population2014_masculin_commune': '211522',
#    'age_moyen_mariage2014_ensemble_commune': 30.0,
#    'age_moyen_mariage2014_feminin_commune': '27.3',
#    'age_moyen_mariage2014_masculin_commune': '32.7',
#    'Taux_handicap2014_Ensemble_commune': 3.9,
#    'Taux_handicap2014_Feminin_commune': '4.2',
#    'Taux_handicap2014_masculin_commune': '3.5',
#    'taux_analphabetisme2014_ensemble_commune': 17.9,
#    'taux_analphabetisme2014_feminin_commune': '25.7',
#    'taux_analphabetisme2014_masculin_commune': '10.1',
#    'tachl7it2014_ensemble_commune': '53.7',
#    'tachl7it2014_feminin_commune': '52',
#    'tachl7it2014_masculin_commune': '55.4',
#    'taux_activite2014_ensemble_commune': '50.8',
#    'taux_activite2014_feminin_commune': 28.0,
#    'taux_activite2014_masculin_commune': '73.5',
# ...

# %%
import json
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client['dbrgph2014']
collection1 = db['region']
#test1=collection1.insert_many(dump['commune'])

client.close()

# %% [markdown]
# <h1> la base de donneé mongodb utilisée dbrgph2014 </h1>

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'database', 'dbrgph', 'dbrgph2014', 'local', 'rgph', 'users']

# %% [markdown]
# <h1> 4) le total de la population municipale du Maroc</h1>

# %%
#4


myquery = db.commune.aggregate([
    {"$group":{"_id":"","population_maroc":{"$sum":"$population2014_ensemble_commune"}}},
    {"$project":{"_id":0,"population_maroc":1}}
    
    
])

for x in myquery:
    print(x)
# Out:
# {'population_maroc': 34737845}

# %% [markdown]
# <h1>5 )les dix premières communes les plus peuplées du Maroc </h1>

# %%
#5
mydoc = db.commune.find({}, {
    "population2014_ensemble_commune": 1,
    "Nom_Commune2014": 1,
    #"_id":0
}).limit(10).sort([
    ("population2014_ensemble_commune", -1)
]);
for x in mydoc:
    print(x)
# Out:
# {'_id': '100', 'population2014_ensemble_commune': 517376, 'Nom_Commune2014': 'Meknès'}
# {'_id': '1056', 'population2014_ensemble_commune': 492873, 'Nom_Commune2014': 'Oujda'}
# {'_id': '304', 'population2014_ensemble_commune': 467880, 'Nom_Commune2014': 'Hay-Hassani'}
# {'_id': '307', 'population2014_ensemble_commune': 452863, 'Nom_Commune2014': 'Sidi Moumen'}
# {'_id': '747', 'population2014_ensemble_commune': 423890, 'Nom_Commune2014': 'Kénitra'}
# {'_id': '0', 'population2014_ensemble_commune': 420288, 'Nom_Commune2014': 'Agadir'}
# {'_id': '909', 'population2014_ensemble_commune': 409829, 'Nom_Commune2014': 'Ménara'}
# {'_id': '1312', 'population2014_ensemble_commune': 385922, 'Nom_Commune2014': 'Bni Makada'}
# {'_id': '1558', 'population2014_ensemble_commune': 377866, 'Nom_Commune2014': 'Tétouan'}
# {'_id': '305', 'population2014_ensemble_commune': 376772, 'Nom_Commune2014': 'Aîn-Chock'}

# %% [markdown]
# <h1> 6)le nombre de communes existant hors les régions de Rabat et Casablanca ayant une population municipale supérieur à 50 000 habitants, un taux de chômage inférieur à 15%, un Taux net d'activité féminin supérieur à 30% et un taux d’analphabétisme inférieur à 20%</h1>

# %%
myquery = db.commune.aggregate([
   {"$match":{"Region_Commune":{"$ne":"Rabat-Salé-Kénitra"}}},
   {"$match":{"Region_Commune":{"$ne":"Casablanca-Settat"}}},
   {"$match":{"population2014_ensemble_commune":{"$gt":50000}}},
   {"$match":{"taux_chaumage2014_ensemble_commune":{"$lt":15.0}}},
   {"$match":{"taux_activite2014_feminin_commune":{"$gt":30.0}}},
   {"$match":{"taux_analphabetisme2014_ensemble_commune":{"$lt":20.0}}}
    
])

# %%
len(list(myquery))
# Out:
# 0

# %% [markdown]
# <h1> 7)la province ayant le taux de prévalence d’handicap le plus faible </h1>

# %%
#7
myquery = db.province.aggregate([
   {"$group":{"_id":"$Nom_province2014","Taux":{"$avg":"$Taux_handicap2014_Ensemble_province"}}},
   {"$sort":{"Taux":1}},
   {"$limit":10},
 
  
   
    
])
for x in myquery:
    print(x)
# Out:
# {'_id': None, 'Taux': None}
# {'_id': 'Oued Ed-Dahab', 'Taux': 2.4}
# {'_id': 'Aousserd', 'Taux': 2.5}
# {'_id': 'Boujdour', 'Taux': 2.7}
# {'_id': 'Laâyoune', 'Taux': 3.4}
# {'_id': 'Tan-Tan', 'Taux': 3.5}
# {'_id': 'Es-Semara', 'Taux': 3.6}
# {'_id': 'Tarfaya', 'Taux': 3.8}
# {'_id': 'Nouaceur', 'Taux': 3.9}
# {'_id': 'Skhirate- Témara', 'Taux': 3.9}

# %% [markdown]
# <h1>  9) les dix communes ayant le taux d’analphabétisme le plus élevé </h1>

# %%
mydoc = db.commune.find({}, {
    "taux_analphabetisme2014_ensemble_commune": 1,
    "Nom_Commune2014": 1,
    "_id":0,
    "Code_Province":1
}).limit(10).sort([
    ("taux_analphabetisme2014_ensemble_commune", -1)
]);

for x in mydoc:
    print(x)
# Out:
# {'taux_analphabetisme2014_ensemble_commune': 85.7, 'Nom_Commune2014': 'Bouchaouene', 'Code_Province': '251'}
# {'taux_analphabetisme2014_ensemble_commune': 78.1, 'Nom_Commune2014': "Oulad M'hammed", 'Code_Province': '533'}
# {'taux_analphabetisme2014_ensemble_commune': 74.8, 'Nom_Commune2014': 'Gueltat Zemmour', 'Code_Province': '121'}
# {'taux_analphabetisme2014_ensemble_commune': 74.2, 'Nom_Commune2014': 'Anemzi', 'Code_Province': '363'}
# {'taux_analphabetisme2014_ensemble_commune': 74.0, 'Nom_Commune2014': 'Oulad Sidi Abdelhakem', 'Code_Province': '275'}
# {'taux_analphabetisme2014_ensemble_commune': 73.6, 'Nom_Commune2014': 'Tindine', 'Code_Province': '541'}
# {'taux_analphabetisme2014_ensemble_commune': 70.2, 'Nom_Commune2014': 'Tahelouante', 'Code_Province': '211'}
# {'taux_analphabetisme2014_ensemble_commune': 70.1, 'Nom_Commune2014': 'Tafajight', 'Code_Province': '451'}
# ...

# %% [markdown]
# <h1> 12 )le nombre de provinces où le taux d’équipement des ménages en parabole est supérieur à celui en réfrigérateur</h1>

# %%
myquery=db.province.aggregate([ {"$group":{"_id":"$Code_province2014"}},
                               {"$match":{"taux_equipement_menage_Parabole2014_province":{"$gt":"taux_equipement_menage_Refrigerateur2014_province"}}},
                             ])

# %%
len(list(myquery))
# Out:
# 36

# %% [markdown]
# <h1> 10)le niveau d'études le plus prépondérant au niveau de chaque région</h1>

# %%
myquery = db.region.aggregate([
   {"$group":{"_id":"$Nom_region2014","Niveau_etudes_néant":{"$max":"$RE_Niveau_études_Néant_Ensemble"}}},
   {"$sort":{"Niveau_etudes":-1}},
   {"$limit":10},
   {"$project":{"Nom_region2014":1,'Niveau_etudes':1 }}
  
   
    
])
for x in myquery:
    print(x)
# Out:
# {'_id': 'Béni Mellal-Khénifra', 'Niveau_etudes': 43.3}
# {'_id': 'Marrakech-Safi', 'Niveau_etudes': 41.7}
# {'_id': 'Drâa-Tafilalet', 'Niveau_etudes': 39.6}
# {'_id': 'Oriental', 'Niveau_etudes': 39.1}
# {'_id': 'Fès-Meknès', 'Niveau_etudes': 38.9}
# {'_id': 'Guelmim-Oued Noun', 'Niveau_etudes': 37.7}
# {'_id': 'Souss-Massa', 'Niveau_etudes': 37.3}
# {'_id': 'Tanger-Tetouan-Al Hoceima', 'Niveau_etudes': 36.1}
# {'_id': 'Rabat-Salé-Kénitra', 'Niveau_etudes': 34.1}
# {'_id': 'Casablanca-Settat', 'Niveau_etudes': 31.4}

# %% [markdown]
# <h1>8 )l’âge moyen au premier mariage par genre (masculin, féminin) et par secteur (urbain, rural) au niveau de chaque région</h1>

# %%
mydoc = db.region.find({}, {
    "RU_age_moyen_mariage2014_masculin": 1,
    "RU_age_moyen_mariage2014_feminin": 1,
    "RR_age_moyen_mariage2014_masculin": 1,
    "RR_age_moyen_mariage2014_feminin": 1,
    "_id":0,
    "Nom_region2014":1
})

for x in mydoc:
    print(x)
# Out:
# {'RU_age_moyen_mariage2014_feminin': 27.0, 'RU_age_moyen_mariage2014_masculin': 31.9, 'RR_age_moyen_mariage2014_feminin': 27.1, 'RR_age_moyen_mariage2014_masculin': 30.9, 'Nom_region2014': 'Tanger-Tetouan-Al Hoceima'}
# {'RU_age_moyen_mariage2014_feminin': 26.6, 'RU_age_moyen_mariage2014_masculin': 32.9, 'RR_age_moyen_mariage2014_feminin': 26.2, 'RR_age_moyen_mariage2014_masculin': 31.8, 'Nom_region2014': 'Oriental'}
# {'RU_age_moyen_mariage2014_feminin': 26.6, 'RU_age_moyen_mariage2014_masculin': 32.1, 'RR_age_moyen_mariage2014_feminin': 25.7, 'RR_age_moyen_mariage2014_masculin': 30.4, 'Nom_region2014': 'Fès-Meknès'}
# {'RU_age_moyen_mariage2014_feminin': 26.8, 'RU_age_moyen_mariage2014_masculin': 32.3, 'RR_age_moyen_mariage2014_feminin': 23.9, 'RR_age_moyen_mariage2014_masculin': 29.7, 'Nom_region2014': 'Rabat-Salé-Kénitra'}
# ...
